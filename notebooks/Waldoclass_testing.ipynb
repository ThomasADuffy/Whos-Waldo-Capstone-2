# %%
import sys
import os
FILE_DIRECTORY = os.path.realpath('')
ROOT_DIRECTORY = os.path.split(FILE_DIRECTORY)[0]
MODEL_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'model')
IMG_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'images')
SRC_DIRECTORY = os.path.join(ROOT_DIRECTORY,'src')
sys.path.append(SRC_DIRECTORY)

# %%
sys.path
# Out:
# ['/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/tf/Documents/Galvanize/Capstones/Waldo-Capstone-2/Whos-Waldo-Capstone-2/src']

# %%
from waldo_CNN import *

# %%
waldo2 = WaldoCNN(50, 10, 'data/Keras Generated/Train',
                     'data/Keras Generated/Test',
                     'data/Keras Generated/Holdout', 3,
                     load_model=os.path.join(MODEL_DIRECTORY,
                                             'model_v2.h5'))
waldo2.fit()
# Out:
# Found 8050 images belonging to 2 classes.
# Found 2013 images belonging to 2 classes.
# Found 21 images belonging to 2 classes.
# Epoch 1/10
# 161/161 [==============================] - 9s 55ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.3991 - val_accuracy: 0.9086
# Epoch 2/10
# 161/161 [==============================] - 8s 52ms/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 0.4819 - val_accuracy: 0.9016
# Epoch 3/10
# 161/161 [==============================] - 8s 52ms/step - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.3442 - val_accuracy: 0.9290
# Epoch 4/10
# 161/161 [==============================] - 8s 51ms/step - loss: 0.0228 - accuracy: 0.9920 - val_loss: 0.0831 - val_accuracy: 0.9712
# Epoch 5/10
# 161/161 [==============================] - 8s 53ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.2990 - val_accuracy: 0.9394
# Epoch 6/10
# ...

# %%
waldo1 = WaldoCNN(50, 10, 'data/Keras Generated/Train',
                     'data/Keras Generated/Test',
                     'data/Keras Generated/Holdout', 3,
                     load_model=os.path.join(MODEL_DIRECTORY,
                                             'model_v1.h5'))
waldo1.fit()
# Out:
# Found 8050 images belonging to 2 classes.
# Found 2013 images belonging to 2 classes.
# Found 21 images belonging to 2 classes.
# Epoch 1/10
# 161/161 [==============================] - 7s 45ms/step - loss: 0.0440 - accuracy: 0.9863 - val_loss: 0.6426 - val_accuracy: 0.8947
# Epoch 2/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.7516 - val_accuracy: 0.9051
# Epoch 3/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.7530 - val_accuracy: 0.9096
# Epoch 4/10
# 161/161 [==============================] - 6s 38ms/step - loss: 0.0199 - accuracy: 0.9927 - val_loss: 0.4554 - val_accuracy: 0.9250
# Epoch 5/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.4891 - val_accuracy: 0.9136
# Epoch 6/10
# ...

# %%
plot_model(waldo1.model, to_file=os.path.join(IMG_DIRECTORY,f'model{waldo1.version}.jpg'),show_shapes=True,expand_nested=True)

# %%
plot_model(waldo2.model, to_file=os.path.join(IMG_DIRECTORY,f'model{waldo2.version}.jpg'),show_shapes=True,expand_nested=True)
